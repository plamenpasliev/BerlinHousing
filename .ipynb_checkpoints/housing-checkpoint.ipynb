# %%
import time 
import random
import pandas as pd
import itertools
import matplotlib.pyplot as plt
import matplotlib.colors as col
import matplotlib
import seaborn as sns
import googlemaps
import folium

from bs4 import BeautifulSoup
from requests import get

sns.set()
# %matplotlib inline

# %% [markdown]
# # Scraping data from https://www.immobilienscout24.de/

# %%
urls = []
streets = []
areas = []
cities = []
prices = []
sqms = []
rooms = []
n_pages = 0

headers = ({'User-Agent':
            'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.36'})

#There are 161 pages of rental properties in Berlin
for page in range(1,161):
    n_pages += 1
    sapo_url = 'https://www.immobilienscout24.de/Suche/de/berlin/berlin/wohnung-mieten?pagenumber='+str(page)
    r = get(sapo_url, headers=headers)
    page_html = BeautifulSoup(r.text, 'html.parser')
    house_containers = page_html.find_all('div', class_="result-list-entry__data")
    if house_containers != []:
        for container in house_containers:
            
            #listing id
            idnum = container.find('button').get('data-id')
            if idnum == None:
                continue
            urls.append('https://www.immobilienscout24.de/expose/' + idnum)
            
            #street and area
            address = container.find_all('div')[1].text
            address = address.split(',')
            
            if len(address)>2:
                street = address[0]
                area = address[1]
                city = address[2]
            elif len(address)==2:
                street = ''
                area = address[0]
                city = address[1]
            else:
                continue
                
            street = street.replace('\n', '')
            area = area.replace(' ', '')
            streets.append(street)
            areas.append(area)
            cities.append(city)
            
            # Price            
            price = container.find_all('div')[5].find_all('dd')[0].text
            price = price.replace(' €', '')
            price = price.replace('.', '')
            price = price.replace(',', '.')
            prices.append(float(price))
            
            #sqm
            sqm = container.find_all('div')[5].find_all('dd')[1].text
            sqm = sqm.replace(' m²', '')
            sqm = sqm.replace(',', '.')
            sqms.append(float(sqm))
            
            #rooms
            room = container.find_all('div')[5].find_all('dd')[2].text
            room = room.split(' ')[0]
            rooms.append(room)
    else:
        break
    
    time.sleep(random.randint(1,2))

print('You scraped {} pages containing {} properties.'.format(n_pages, len(areas)))
# Out:
# You scraped 160 pages containing 3189 properties.

# %%
results = pd.DataFrame({
    'Street': streets,
    'Area': areas,
    'City': cities,
    'Price': prices,
    'sqm': sqms,
    'Rooms': rooms,
    'Url' : urls
})

# %%
results['PricePerSqm'] = results.Price / results.sqm

# %% [markdown]
# # EDA

# %%
len(results.Area.value_counts())
# Out:
# 85

# %%
#only 80 areas with more than 5 listings
(results.Area.value_counts()>5).sum()
# Out:
# 65

# %%
areas = results.Area.value_counts().index[:66]

# %%
#get results only in the top 64 areas
results = results[results.Area.isin(areas)]

# %%
results.Area.value_counts()
# Out:
# Tiergarten(Tiergarten)                    357
# Mitte(Mitte)                              252
# Charlottenburg(Charlottenburg)            223
# Friedrichshain(Friedrichshain)            161
# Wedding(Wedding)                          145
# Neukölln(Neukölln)                        134
# PrenzlauerBerg(PrenzlauerBerg)            128
# Wilmersdorf(Wilmersdorf)                  123
# Kreuzberg(Kreuzberg)                      110
# Köpenick(Köpenick)                        107
# Spandau(Spandau)                          107
# Schöneberg(Schöneberg)                     73
# Hellersdorf(Hellersdorf)                   70
# Lichterfelde(Steglitz)                     58
# Reinickendorf(Reinickendorf)               54
# Pankow(Pankow)                             53
# Lichtenberg(Lichtenberg)                   52
# Oberschöneweide(Köpenick)                  48
# Friedrichsfelde(Lichtenberg)               47
# Weißensee(Weißensee)                       42
# Alt-Hohenschönhausen(Hohenschönhausen)     41
# Steglitz(Steglitz)                         37
# Schmargendorf(Wilmersdorf)                 36
# Adlershof(Treptow)                         31
# Tempelhof(Tempelhof)                       30
# Lichtenrade(Tempelhof)                     27
# Tegel(Reinickendorf)                       25
# Marzahn(Marzahn)                           25
# Grunewald(Wilmersdorf)                     24
# Niederschönhausen(Pankow)                  24
#                                          ...
# Biesdorf(Marzahn)                          21
# Niederschöneweide(Treptow)                 20
# Zehlendorf(Zehlendorf)                     20
# Grünau(Köpenick)                           19
# Buckow(Neukölln)                           19
# Rosenthal(Pankow)                          18
# Marienfelde(Tempelhof)                     18
# Mariendorf(Tempelhof)                      18
# Friedenau(Schöneberg)                      17
# Wannsee(Zehlendorf)                        16
# Baumschulenweg(Treptow)                    15
# Neu-Hohenschönhausen(Hohenschönhausen)     14
# Wittenau(Reinickendorf)                    14
# Karlshorst(Lichtenberg)                    12
# Lankwitz(Steglitz)                         12
# Mahlsdorf(Hellersdorf)                     12
# Friedrichshagen(Köpenick)                  11
# Siemensstadt(Spandau)                      10
# Heinersdorf(Weißensee)                     10
# Altglienicke(Treptow)                      10
# Hermsdorf(Reinickendorf)                    9
# Rahnsdorf(Köpenick)                         9
# Rudow(Neukölln)                             9
# Frohnau(Reinickendorf)                      7
# Plänterwald(Treptow)                        6
# Kladow(Spandau)                             6
# Kaulsdorf(Hellersdorf)                      6
# Treptow(Treptow)                            6
# Müggelheim(Köpenick)                        6
# Buch(Pankow)                                5
# Name: Area, Length: 66, dtype: int64

# %%
len(results)
# Out:
# 3152

# %%
results.head(30)
# Out:
#                      Street                            Area     City    Price  \
# 0   Schnackenburgstr. 12-13           Friedenau(Schöneberg)   Berlin   409.00
# 1         Emdener Straße 29          Tiergarten(Tiergarten)   Berlin   318.14
# 2           Eichborndamm 39    Reinickendorf(Reinickendorf)   Berlin   458.42
# 3       Mariendorfer Weg 49              Neukölln(Neukölln)   Berlin  1057.00
# 4        Danziger Straße 73  PrenzlauerBerg(PrenzlauerBerg)   Berlin  1459.00
# 5   Stallschreiberstraße 27                    Mitte(Mitte)   Berlin  1799.00
# 6       Schöneberger Ufer 5            Kreuzberg(Kreuzberg)   Berlin   887.68
# 7      Fraunhoferstraße  22  Charlottenburg(Charlottenburg)   Berlin  2355.86
# 9        Bismarckstraße  80  Charlottenburg(Charlottenburg)   Berlin  2225.70
# 10          Zeppelinstr. 85                Spandau(Spandau)   Berlin   497.17
# 11        Groener Straße 19                Spandau(Spandau)   Berlin  1016.00
# 12              Weverstr. 7                Spandau(Spandau)   Berlin   532.19
# 13      Mariendorfer Weg 53              Neukölln(Neukölln)   Berlin  1563.89
# 14        Glienicker Str. 6              Köpenick(Köpenick)   Berlin   753.30
# 15          Luisenstraße 50                    Mitte(Mitte)   Berlin  1530.00
# 16  Stallschreiberstraße 31                    Mitte(Mitte)   Berlin  2249.00
# 17                                             Mitte(Mitte)   Berlin  1813.00
# 18                                             Mitte(Mitte)   Berlin  5100.00
# 19       Hofzeichendamm 13b                Karow(Weißensee)   Berlin   780.50
# 20                                             Mitte(Mitte)   Berlin  2720.00
# 21           Im Lindenhof 1        Lichtenberg(Lichtenberg)   Berlin   714.00
# 22           Am Lokdepot 13            Kreuzberg(Kreuzberg)   Berlin  1799.00
# 23     Angerburger Allee 51  Charlottenburg(Charlottenburg)   Berlin   382.08
# 24        Hakenfelderstr. 9                Spandau(Spandau)   Berlin   440.67
# 25             Stromstr. 40          Tiergarten(Tiergarten)   Berlin   455.68
# 26    Ueckermünder Straße 2  PrenzlauerBerg(PrenzlauerBerg)   Berlin   650.00
# 27       Malteserstraße 148          Marienfelde(Tempelhof)   Berlin   847.00
# 28           Goldfinkweg 40      Schmargendorf(Wilmersdorf)   Berlin  2938.00
# 29            Hasenheide 74              Neukölln(Neukölln)   Berlin  1697.49
# 30             Torstraße 72                    Mitte(Mitte)   Berlin  2849.00
#
#        sqm Rooms                                                Url  \
# 0    32.00     1  https://www.immobilienscout24.de/expose/115230398
# 1    36.61     1  https://www.immobilienscout24.de/expose/115205963
# 2    50.00     2   https://www.immobilienscout24.de/expose/84230002
# 3    68.22     3  https://www.immobilienscout24.de/expose/114864184
# 4    75.02     2  https://www.immobilienscout24.de/expose/113885749
# 5    95.80     4  https://www.immobilienscout24.de/expose/115478066
# 6    24.82     1  https://www.immobilienscout24.de/expose/115238928
# 7   168.24     5  https://www.immobilienscout24.de/expose/110356560
# 9   148.38     3  https://www.immobilienscout24.de/expose/111917240
# 10   60.52     2  https://www.immobilienscout24.de/expose/115168796
# 11  112.67     4  https://www.immobilienscout24.de/expose/115461269
# 12   65.46     2  https://www.immobilienscout24.de/expose/115439152
# 13   90.66     3  https://www.immobilienscout24.de/expose/114988471
# 14   77.82     3  https://www.immobilienscout24.de/expose/115302916
# 15  102.00     3  https://www.immobilienscout24.de/expose/113704438
# 16  125.20     4  https://www.immobilienscout24.de/expose/114437800
# 17   65.94     2  https://www.immobilienscout24.de/expose/115288585
# 18  123.00     2  https://www.immobilienscout24.de/expose/114012650
# 19   62.44     2  https://www.immobilienscout24.de/expose/108484203
# 20   68.00     2  https://www.immobilienscout24.de/expose/113897977
# 21   55.00     2  https://www.immobilienscout24.de/expose/115402056
# 22  115.00     3  https://www.immobilienscout24.de/expose/115025698
# 23   48.00   1,5  https://www.immobilienscout24.de/expose/115171548
# 24   70.00     2  https://www.immobilienscout24.de/expose/115171447
# 25   34.23     1   https://www.immobilienscout24.de/expose/90622511
# 26   34.00     1  https://www.immobilienscout24.de/expose/115273129
# 27   30.00     1  https://www.immobilienscout24.de/expose/115239740
# 28  113.00     3   https://www.immobilienscout24.de/expose/91496497
# 29  106.09     4  https://www.immobilienscout24.de/expose/115221182
# 30  145.00     4  https://www.immobilienscout24.de/expose/113736012
#
#     PricePerSqm
# 0     12.781250
# 1      8.689975
# 2      9.168400
# 3     15.493990
# 4     19.448147
# 5     18.778706
# 6     35.764706
# 7     14.002972
# 9     15.000000
# 10     8.214970
# 11     9.017485
# 12     8.130003
# 13    17.250055
# 14     9.680031
# 15    15.000000
# 16    17.963259
# 17    27.494692
# 18    41.463415
# 19    12.500000
# 20    40.000000
# 21    12.981818
# 22    15.643478
# 23     7.960000
# 24     6.295286
# 25    13.312299
# 26    19.117647
# 27    28.233333
# 28    26.000000
# 29    16.000471
# 30    19.648276

# %%
sns.pairplot(results)

# %%
mean_per_area = results.groupby('Area').mean()

# %% [markdown]
# # Mean price per square meter sorted alphabetically

# %%
fig = plt.figure(figsize=(10,15))
sns.barplot(mean_per_area.PricePerSqm, mean_per_area.index)

# %% [markdown]
# # Mean price per square meter sorted by value

# %%
mean_per_area.sort_values(by='PricePerSqm', ascending=False, inplace=True)
fig = plt.figure(figsize=(10,15))
sns.barplot(mean_per_area.PricePerSqm, mean_per_area.index)

# %% [markdown]
# # Getting coordinates with Google Geocoder

# %%
gmaps = googlemaps.Client(key='your-api-key-here')

# %%
lat = []
lng = []
for index, row in results.iterrows():
    if row.Street != '':
        geocode_result = gmaps.geocode(row.Street + row.Area + ', Berlin')
    else:
        geocode_result = gmaps.geocode(row.Area + ', Berlin')
    lat.append(geocode_result[0]['geometry']['location']['lat'])
    lng.append(geocode_result[0]['geometry']['location']['lng'])
    
    if index%300 == 0:
        print('Got {} coordinates!'.format(index))
# Out:
# Got 0 coordinates!
# Got 300 coordinates!
# Got 600 coordinates!
# Got 900 coordinates!
# Got 1200 coordinates!
# Got 1500 coordinates!
# Got 1800 coordinates!
# Got 2100 coordinates!
# Got 2400 coordinates!
# Got 2700 coordinates!
# Got 3000 coordinates!

# %%
results['lat'] = lat
results['lng'] = lng

# %%
results.head(15)
# Out:
#                      Street                            Area     City    Price  \
# 0   Schnackenburgstr. 12-13           Friedenau(Schöneberg)   Berlin   409.00
# 1         Emdener Straße 29          Tiergarten(Tiergarten)   Berlin   318.14
# 2           Eichborndamm 39    Reinickendorf(Reinickendorf)   Berlin   458.42
# 3       Mariendorfer Weg 49              Neukölln(Neukölln)   Berlin  1057.00
# 4        Danziger Straße 73  PrenzlauerBerg(PrenzlauerBerg)   Berlin  1459.00
# 5   Stallschreiberstraße 27                    Mitte(Mitte)   Berlin  1799.00
# 6       Schöneberger Ufer 5            Kreuzberg(Kreuzberg)   Berlin   887.68
# 7      Fraunhoferstraße  22  Charlottenburg(Charlottenburg)   Berlin  2355.86
# 9        Bismarckstraße  80  Charlottenburg(Charlottenburg)   Berlin  2225.70
# 10          Zeppelinstr. 85                Spandau(Spandau)   Berlin   497.17
# 11        Groener Straße 19                Spandau(Spandau)   Berlin  1016.00
# 12              Weverstr. 7                Spandau(Spandau)   Berlin   532.19
# 13      Mariendorfer Weg 53              Neukölln(Neukölln)   Berlin  1563.89
# 14        Glienicker Str. 6              Köpenick(Köpenick)   Berlin   753.30
# 15          Luisenstraße 50                    Mitte(Mitte)   Berlin  1530.00
#
#        sqm Rooms                                                Url  \
# 0    32.00     1  https://www.immobilienscout24.de/expose/115230398
# 1    36.61     1  https://www.immobilienscout24.de/expose/115205963
# 2    50.00     2   https://www.immobilienscout24.de/expose/84230002
# 3    68.22     3  https://www.immobilienscout24.de/expose/114864184
# 4    75.02     2  https://www.immobilienscout24.de/expose/113885749
# 5    95.80     4  https://www.immobilienscout24.de/expose/115478066
# 6    24.82     1  https://www.immobilienscout24.de/expose/115238928
# 7   168.24     5  https://www.immobilienscout24.de/expose/110356560
# 9   148.38     3  https://www.immobilienscout24.de/expose/111917240
# 10   60.52     2  https://www.immobilienscout24.de/expose/115168796
# 11  112.67     4  https://www.immobilienscout24.de/expose/115461269
# 12   65.46     2  https://www.immobilienscout24.de/expose/115439152
# 13   90.66     3  https://www.immobilienscout24.de/expose/114988471
# 14   77.82     3  https://www.immobilienscout24.de/expose/115302916
# 15  102.00     3  https://www.immobilienscout24.de/expose/113704438
#
#     PricePerSqm        lat        lng
# 0     12.781250  52.474258  13.333949
# 1      8.689975  52.530583  13.334164
# 2      9.168400  52.571650  13.313080
# 3     15.493990  52.462873  13.422719
# 4     19.448147  52.539535  13.425363
# 5     18.778706  52.508521  13.406499
# 6     35.764706  52.502697  13.373920
# 7     14.002972  52.515787  13.318043
# 9     15.000000  52.511208  13.304678
# 10     8.214970  52.546338  13.184756
# 11     9.017485  52.543221  13.203022
# 12     8.130003  52.519445  13.195728
# 13    17.250055  52.463994  13.427605
# 14     9.680031  52.441570  13.568770
# 15    15.000000  52.524103  13.379575

# %%
#save to csv
results.to_csv('housing_data.csv', index=False)

# %% [markdown]
# # Getting distance to nearest stations and markets via Google Places

# %%
all_stations = []
all_supermarkets = []

for i in range(len(lat)):
    coordinate = lat[i], lng[i]
    stations = []
    stations_placeid = []
    supermarkets = []
    supermarkets_placeid = []
    
    #stations
    transit_stations = gmaps.places_nearby(location=coordinate, radius=500, type='transit_station')
    for station in transit_stations['results']:
        stations.append(station['name'])
        stations_placeid.append(station['place_id'])
    all_stations.append((stations, stations_placeid))
    
    #supermarkets
    markets = gmaps.places_nearby(location=coordinate, radius=500, type='supermarket')
    for market in markets['results']:
        supermarkets.append(market['name'])
        supermarkets_placeid.append(market['place_id'])
    all_supermarkets.append((supermarkets, supermarkets_placeid))
    
    if i%300 == 0:
        print('Got {} results!'.format(i))
# Out:
# Got 0 results!
# Got 300 results!
# Got 600 results!
# Got 900 results!
# Got 1200 results!
# Got 1500 results!
# Got 1800 results!
# Got 2100 results!
# Got 2400 results!
# Got 2700 results!
# Got 3000 results!

# %%
results['stations'] = all_stations
results['supermarkets'] = all_supermarkets
results.to_csv('housing_data.csv', index=False)

# %%
results.head()
# Out:
#                     Street                            Area     City    Price  \
# 0  Schnackenburgstr. 12-13           Friedenau(Schöneberg)   Berlin   409.00
# 1        Emdener Straße 29          Tiergarten(Tiergarten)   Berlin   318.14
# 2          Eichborndamm 39    Reinickendorf(Reinickendorf)   Berlin   458.42
# 3      Mariendorfer Weg 49              Neukölln(Neukölln)   Berlin  1057.00
# 4       Danziger Straße 73  PrenzlauerBerg(PrenzlauerBerg)   Berlin  1459.00
#
#      sqm Rooms                                                Url  \
# 0  32.00     1  https://www.immobilienscout24.de/expose/115230398
# 1  36.61     1  https://www.immobilienscout24.de/expose/115205963
# 2  50.00     2   https://www.immobilienscout24.de/expose/84230002
# 3  68.22     3  https://www.immobilienscout24.de/expose/114864184
# 4  75.02     2  https://www.immobilienscout24.de/expose/113885749
#
#    PricePerSqm        lat        lng  \
# 0    12.781250  52.474258  13.333949
# 1     8.689975  52.530583  13.334164
# 2     9.168400  52.571650  13.313080
# 3    15.493990  52.462873  13.422719
# 4    19.448147  52.539535  13.425363
#
#                                             stations  \
# 0  ([Breslauer Platz (Berlin), Hähnelstr. (Berlin...
# 1  ([Wittstocker Str. (Berlin), Rathaus Tiergarte...
# 2  ([Eichborndamm/Antonienstr. (Berlin), Auguste-...
# 3  ([Mariendorfer Weg (Berlin), Eschersheimer Str...
# 4  ([Prenzlauer Allee/Danziger Str. (Berlin), Frö...
#
#                                         supermarkets
# 0  ([Netto Filiale, EDEKA Scheibner, denn's Bioma...
# 1  ([Arminius Market Hall, NORMA Filiale, dm-drog...
# 2  ([nahkauf, EDEKA Görse & Meichsner, Intermarkt...
# 3  ([ALDI Berlin-Neukölln], [ChIJfV1jLJBPqEcRUDDg...
# 4  ([denn's Biomarkt, Lidl, PENNY, Arin Spätkauf,...

# %% [markdown]
# # Plotting results with Folium

# %%
m = folium.Map(
    location=[52.524103, 13.379575],
    zoom_start=12
)

cmap = matplotlib.cm.get_cmap('bwr')
norm = matplotlib.colors.Normalize(vmin=7, vmax=23)

for index, row in results.iterrows():
    #top section
    html="""
        <h4><a href={url} target="_blank">Original listing</a></h4>
        <ul>
          <li>{street}</li>
          <li>Price: {price} &euro;</li>
          <li>Sqm: {sqm} &#13217;</li>
          <li>Rooms: {rooms}</li>
          <li>Price/sqm: {psqm:.2f} &euro;</li>
          <li>Mean price/sqm in {area}: {mean:.2f} &euro;</li>
          <li>Difference: {delta:.2f} &euro;</li>
        </ul>
        """.format(
                street = row.Street, 
                price = row.Price, 
                sqm = row.sqm, 
                rooms = row.Rooms, 
                psqm = row.PricePerSqm,
                url = row.Url,
                area = row.Area,
                mean = mean_per_area[mean_per_area.index == row.Area].PricePerSqm.values[0],
                delta = row.PricePerSqm - mean_per_area[mean_per_area.index == row.Area].PricePerSqm.values[0]
            )
    #Stations
    html = html + '<h4>Stations within 500m radius:</h4> <ul>' #heading and start of list
    if (len(row.stations[0]) != 0):
        for i in range(len(row.stations[0])):
            html = html + """
                    <li>
                        <a href=https://www.google.com/maps/place/?q=place_id:{place_id} target="_blank">
                            {name}
                        </a>
                    </li>
                """.format(
                    place_id = row.stations[1][i], 
                    name = row.stations[0][i]
                )
    else:
        html = html + """
                    <li>
                        None!
                    </li>
                """
    html = html + '</ul>' #end of list
    
    #Markets
    html = html + '<h4>Supermarkets within 500m radius:</h4> <ul>' #heading and start of list
    if (len(row.supermarkets[0]) != 0):
        for i in range(len(row.supermarkets[0])):
            html = html + """
                    <li>
                        <a href=https://www.google.com/maps/place/?q=place_id:{place_id} target="_blank">
                            {name}
                        </a>
                    </li>
                """.format(
                    place_id = row.supermarkets[1][i], 
                    name = row.supermarkets[0][i]
                )
    else:
        html = html + """
                    <li>
                        None!
                    </li>
                """
    html = html + '</ul>' #end of list
    
    
    iframe = folium.IFrame(html=html, width=250, height=220)
    popup = folium.Popup(iframe, max_width=300)

    
    folium.Circle(
        location=[row.lat, row.lng],
        radius=110,
        popup=popup,
        color=col.to_hex(cmap(norm(row.PricePerSqm))),
        fill=True,
        fill_opacity = 0.5
    ).add_to(m)
    
m.save('housing.html')
