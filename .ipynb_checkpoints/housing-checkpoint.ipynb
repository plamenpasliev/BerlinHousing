# %%
from bs4 import BeautifulSoup
from requests import get
import pandas as pd
import itertools
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
# %matplotlib inline

# %% [markdown]
# # Scraping data from https://www.immobilienscout24.de/

# %%
import time 
import random
streets = []
areas = []
prices = []
sqms = []
rooms = []
n_pages = 0

headers = ({'User-Agent':
            'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.36'})

#There are 161 pages of rental properties in Berlin
for page in range(1,161):
    n_pages += 1
    sapo_url = 'https://www.immobilienscout24.de/Suche/de/berlin/berlin/wohnung-mieten?pagenumber='+str(page)
    r = get(sapo_url, headers=headers)
    page_html = BeautifulSoup(r.text, 'html.parser')
    house_containers = page_html.find_all('div', class_="result-list-entry__data")
    if house_containers != []:
        for container in house_containers:
            
            #street and area
            address = container.find_all('div')[1].text
            address = address.split(',')
            
            if len(address)>2:
                street = address[0]
                area = address[1]
            elif len(address)==2:
                street = ''
                area = address[0]
            else:
                continue
                
            street = street.replace('\n', '')
            area = area.replace(' ', '')
            streets.append(street)
            areas.append(area)
            
            # Price            
            price = container.find_all('div')[5].find_all('dd')[0].text
            price = price.replace(' €', '')
            price = price.replace('.', '')
            price = price.replace(',', '.')
            prices.append(float(price))
            
            #sqm
            sqm = container.find_all('div')[5].find_all('dd')[1].text
            sqm = sqm.replace(' m²', '')
            sqm = sqm.replace(',', '.')
            sqms.append(float(sqm))
            
            #rooms
            room = container.find_all('div')[5].find_all('dd')[2].text
            room = room.split(' ')[0]
            rooms.append(room)
    else:
        break
    
    time.sleep(random.randint(1,2))

print('You scraped {} pages containing {} properties.'.format(n_pages, len(areas)))
# Out:
# You scraped 160 pages containing 3189 properties.

# %%
results = pd.DataFrame({
    'Street': streets,
    'Area': areas,
    'Price': prices,
    'sqm': sqms,
    'Rooms': rooms
})

# %%
results['PricePerSqm'] = results.Price / results.sqm

# %% [markdown]
# # EDA

# %%
len(results.Area.value_counts())
# Out:
# 85

# %%
#only 80 areas with more than 5 listings
(results.Area.value_counts()>5).sum()
# Out:
# 64

# %%
areas = results.Area.value_counts().index[:64]

# %%
#get results only in the top 64 areas
results = results[results.Area.isin(areas)]

# %%
results.Area.value_counts()
# Out:
# Tiergarten(Tiergarten)                    358
# Mitte(Mitte)                              245
# Charlottenburg(Charlottenburg)            228
# Friedrichshain(Friedrichshain)            167
# Wedding(Wedding)                          138
# Neukölln(Neukölln)                        137
# PrenzlauerBerg(PrenzlauerBerg)            129
# Wilmersdorf(Wilmersdorf)                  122
# Köpenick(Köpenick)                        109
# Kreuzberg(Kreuzberg)                      104
# Spandau(Spandau)                          100
# Schöneberg(Schöneberg)                     74
# Hellersdorf(Hellersdorf)                   72
# Reinickendorf(Reinickendorf)               56
# Pankow(Pankow)                             55
# Lichterfelde(Steglitz)                     53
# Lichtenberg(Lichtenberg)                   51
# Oberschöneweide(Köpenick)                  48
# Friedrichsfelde(Lichtenberg)               44
# Weißensee(Weißensee)                       44
# Alt-Hohenschönhausen(Hohenschönhausen)     40
# Steglitz(Steglitz)                         39
# Schmargendorf(Wilmersdorf)                 37
# Adlershof(Treptow)                         31
# Tempelhof(Tempelhof)                       30
# Lichtenrade(Tempelhof)                     29
# Niederschönhausen(Pankow)                  28
# Tegel(Reinickendorf)                       27
# Grunewald(Wilmersdorf)                     24
# Britz(Neukölln)                            24
#                                          ...
# Dahlem(Zehlendorf)                         22
# Marienfelde(Tempelhof)                     21
# Grünau(Köpenick)                           20
# Buckow(Neukölln)                           20
# Staaken(Spandau)                           20
# Niederschöneweide(Treptow)                 20
# Karow(Weißensee)                           19
# Rosenthal(Pankow)                          18
# Mariendorf(Tempelhof)                      18
# Zehlendorf(Zehlendorf)                     17
# Friedenau(Schöneberg)                      16
# Wannsee(Zehlendorf)                        16
# Baumschulenweg(Treptow)                    15
# Wittenau(Reinickendorf)                    15
# Neu-Hohenschönhausen(Hohenschönhausen)     14
# Mahlsdorf(Hellersdorf)                     14
# Lankwitz(Steglitz)                         12
# Karlshorst(Lichtenberg)                    11
# Friedrichshagen(Köpenick)                  11
# Siemensstadt(Spandau)                      11
# Altglienicke(Treptow)                      10
# Rahnsdorf(Köpenick)                        10
# Heinersdorf(Weißensee)                     10
# Hermsdorf(Reinickendorf)                    9
# Kladow(Spandau)                             7
# Rudow(Neukölln)                             7
# Frohnau(Reinickendorf)                      7
# Kaulsdorf(Hellersdorf)                      6
# Buch(Pankow)                                6
# Müggelheim(Köpenick)                        6
# Name: Area, Length: 64, dtype: int64

# %%
len(results)
# Out:
# 3140

# %%
results.head(30)
# Out:
#                      Street                            Area    Price     sqm  \
# 0      Fraunhoferstraße  22  Charlottenburg(Charlottenburg)  2355.86  168.24
# 2        Bismarckstraße  80  Charlottenburg(Charlottenburg)  2225.70  148.38
# 3           Huttenstraße 72          Tiergarten(Tiergarten)  1541.00  119.47
# 4           Zeppelinstr. 85                Spandau(Spandau)   497.17   60.52
# 5         Groener Straße 19                Spandau(Spandau)  1016.00  112.67
# 6               Weverstr. 7                Spandau(Spandau)   532.19   65.46
# 7        Am Hohen Feld 125a                Karow(Weißensee)  1158.95   89.15
# 8        Am Hohen Feld 125a                Karow(Weißensee)   799.32   66.61
# 9              Alt-Britz 88                 Britz(Neukölln)   950.00  112.00
# 10      Mariendorfer Weg 53              Neukölln(Neukölln)  1341.00   95.81
# 11        Alt-Müggelheim 17            Müggelheim(Köpenick)   833.00   86.20
# 12        Glienicker Str. 6              Köpenick(Köpenick)   753.30   77.82
# 13       Danziger Straße 73  PrenzlauerBerg(PrenzlauerBerg)  1749.00   92.62
# 14          Luisenstraße 50                    Mitte(Mitte)  1530.00  102.00
# 15  Stallschreiberstraße 31                    Mitte(Mitte)  2249.00  125.20
# 16                                             Mitte(Mitte)  1813.00   65.94
# 17                                             Mitte(Mitte)  5100.00  123.00
# 18       Hofzeichendamm 13b                Karow(Weißensee)   780.50   62.44
# 19                                             Mitte(Mitte)  2720.00   68.00
# 20           Im Lindenhof 1        Lichtenberg(Lichtenberg)   714.00   55.00
# 21           Am Lokdepot 13            Kreuzberg(Kreuzberg)  1799.00  115.00
# 22  Schnackenburgstr. 12-13           Friedenau(Schöneberg)   409.00   32.00
# 23        Emdener Straße 29          Tiergarten(Tiergarten)   318.14   36.61
# 24          Eichborndamm 39    Reinickendorf(Reinickendorf)   458.42   50.00
# 25       Danziger Straße 73  PrenzlauerBerg(PrenzlauerBerg)  1459.00   75.02
# 26      Schöneberger Ufer 5            Kreuzberg(Kreuzberg)   887.68   24.82
# 27          Moselstraße 7-8           Friedenau(Schöneberg)  1993.00  128.56
# 28     Isländische Straße 5  PrenzlauerBerg(PrenzlauerBerg)   534.11   56.70
# 29     Wünsdorfer Straße 16          Lichtenrade(Tempelhof)  1360.00  143.07
# 30            Kaiserkorso 6            Tempelhof(Tempelhof)   523.00   46.41
#
#    Rooms  PricePerSqm
# 0      5    14.002972
# 2      3    15.000000
# 3      4    12.898636
# 4      2     8.214970
# 5      4     9.017485
# 6      2     8.130003
# 7      3    13.000000
# 8      2    12.000000
# 9      3     8.482143
# 10     4    13.996451
# 11     3     9.663573
# 12     3     9.680031
# 13     3    18.883610
# 14     3    15.000000
# 15     4    17.963259
# 16     2    27.494692
# 17     2    41.463415
# 18     2    12.500000
# 19     2    40.000000
# 20     2    12.981818
# 21     3    15.643478
# 22     1    12.781250
# 23     1     8.689975
# 24     2     9.168400
# 25     2    19.448147
# 26     1    35.764706
# 27     3    15.502489
# 28     2     9.419929
# 29     5     9.505836
# 30     2    11.269123

# %%
sns.pairplot(results)

# %%
mean_per_area = results.groupby('Area').mean()

# %% [markdown]
# # Mean price per square meter sorted alphabetically

# %%
fig = plt.figure(figsize=(10,15))
sns.barplot(mean_per_area.PricePerSqm, mean_per_area.index)

# %% [markdown]
# # Mean price per square meter sorted by value

# %%
mean_per_area.sort_values(by='PricePerSqm', ascending=False, inplace=True)
fig = plt.figure(figsize=(10,15))
sns.barplot(mean_per_area.PricePerSqm, mean_per_area.index)

# %%
sns.boxplot()

# %% [markdown]
# # Getting coordinates with Google maps

# %%
import googlemaps
gmaps = googlemaps.Client(key='hidden')

# %%
lat = []
lng = []
for index, row in results.iterrows():
    if row.Street != '':
        geocode_result = gmaps.geocode(row.Street + ', Berlin')
    else:
        geocode_result = gmaps.geocode(row.Area + ', Berlin')
    lat.append(geocode_result[0]['geometry']['location']['lat'])
    lng.append(geocode_result[0]['geometry']['location']['lng'])
    
    if index%300 == 0:
        print('Got {} coordinates!'.format(index))
# Out:
# Got 0 coordinates!
# Got 300 coordinates!
# Got 600 coordinates!
# Got 900 coordinates!
# Got 1200 coordinates!
# Got 1500 coordinates!
# Got 1800 coordinates!
# Got 2100 coordinates!
# Got 2400 coordinates!
# Got 2700 coordinates!
# Got 3000 coordinates!

# %%
results['lat'] = lat
results['lng'] = lng

# %%
results.head(15)
# Out:
#                      Street                            Area    Price     sqm  \
# 0      Fraunhoferstraße  22  Charlottenburg(Charlottenburg)  2355.86  168.24
# 2        Bismarckstraße  80  Charlottenburg(Charlottenburg)  2225.70  148.38
# 3           Huttenstraße 72          Tiergarten(Tiergarten)  1541.00  119.47
# 4           Zeppelinstr. 85                Spandau(Spandau)   497.17   60.52
# 5         Groener Straße 19                Spandau(Spandau)  1016.00  112.67
# 6               Weverstr. 7                Spandau(Spandau)   532.19   65.46
# 7        Am Hohen Feld 125a                Karow(Weißensee)  1158.95   89.15
# 8        Am Hohen Feld 125a                Karow(Weißensee)   799.32   66.61
# 9              Alt-Britz 88                 Britz(Neukölln)   950.00  112.00
# 10      Mariendorfer Weg 53              Neukölln(Neukölln)  1341.00   95.81
# 11        Alt-Müggelheim 17            Müggelheim(Köpenick)   833.00   86.20
# 12        Glienicker Str. 6              Köpenick(Köpenick)   753.30   77.82
# 13       Danziger Straße 73  PrenzlauerBerg(PrenzlauerBerg)  1749.00   92.62
# 14          Luisenstraße 50                    Mitte(Mitte)  1530.00  102.00
# 15  Stallschreiberstraße 31                    Mitte(Mitte)  2249.00  125.20
#
#    Rooms  PricePerSqm        lat        lng
# 0      5    14.002972  52.515787  13.318043
# 2      3    15.000000  52.511208  13.304678
# 3      4    12.898636  52.527298  13.328142
# 4      2     8.214970  52.546338  13.184756
# 5      4     9.017485  52.543221  13.203022
# 6      2     8.130003  52.519660  13.201092
# 7      3    13.000000  52.613974  13.496126
# 8      2    12.000000  52.613974  13.496126
# 9      3     8.482143  52.446412  13.436219
# 10     4    13.996451  52.463994  13.427605
# 11     3     9.663573  52.412294  13.662552
# 12     3     9.680031  52.617692  13.308423
# 13     3    18.883610  52.539535  13.425363
# 14     3    15.000000  52.524103  13.379575
# 15     4    17.963259  52.507396  13.406488

# %%
#save to csv
results.to_csv('housing_data.csv', index=False)

# %% [markdown]
# # Plotting results with Folium

# %%
import matplotlib.colors as col
import matplotlib
import folium
m = folium.Map(
    location=[52.524103, 13.379575],
    zoom_start=12
)

cmap = matplotlib.cm.get_cmap('bwr')
norm = matplotlib.colors.Normalize(vmin=7, vmax=23)

for index, row in results.iterrows():
    
    folium.Circle(
        location=[row.lat, row.lng],
        radius=110,
        popup='{} \n Price: {} \n Sqm: {} \n Rooms: {} \n PricePerSqm: {}'.format(
            row.Street, row.Price, row.sqm, row.Rooms, row.PricePerSqm
        ),
        color=col.to_hex(cmap(norm(row.PricePerSqm))),
        fill=True,
        fill_opacity = 0.5
    ).add_to(m)
    
m.save('housing.html')
